# %%
import pandas as pd
import sqlite3 as sql
from contextlib import closing

# %%
df = pd.read_csv("../data/Goodreads_books_with_genres.csv")
df = df.drop(axis=0, index=8180) # parche
df = df.drop(axis=0, index=11098) # parche
df["Author"] = df["Author"].str.replace('"',"'")
df['publication_date'] = pd.to_datetime(df['publication_date'], format='%m/%d/%Y')
df.head()
# Out:
#    Book Id                                              Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code  num_pages  ratings_count  text_reviews_count  \
# 0           eng        652        2095690               27591
# 1           eng        870        2153167               29221
# 2           eng        352           6333                 244
# 3           eng        435        2339585               36325
# 4           eng       2690          41428                 164
#
#   publication_date        publisher  \
# 0       2006-09-16  Scholastic Inc.
# 1       2004-09-01  Scholastic Inc.
# 2       2003-11-01       Scholastic
# 3       2004-05-01  Scholastic Inc.
# 4       2004-09-13       Scholastic
#
#                                               genres
# 0  Fantasy;Young Adult;Fiction;Fantasy,Magic;Chil...
# 1  Fantasy;Young Adult;Fiction;Fantasy,Magic;Chil...
# 2  Fantasy;Fiction;Young Adult;Fantasy,Magic;Chil...
# 3  Fantasy;Fiction;Young Adult;Fantasy,Magic;Chil...
# 4  Fantasy;Young Adult;Fiction;Fantasy,Magic;Adve...

# %% [markdown]
# Llenar tabla de géneros. Para eso necesito obtener todos los géneros individuales

# %%
series_genres = df['genres'].dropna()
list_genres = series_genres.str.split(pat=";").values.tolist()
# Flatten genres
flat_list_genres = [x2 for x1 in list_genres for x2 in x1]
# Capitalizar todos
flat_list_genres_cap = [x.capitalize().strip() for x in flat_list_genres]
array_genres_unique = pd.Series(flat_list_genres_cap).unique()
array_genres_unique
# Out:
# array(['Fantasy', 'Young adult', 'Fiction', 'Fantasy,magic', 'Childrens',
#        'Adventure', 'Audiobook', 'Childrens,middle grade', 'Classics',
#        'Science fiction fantasy', 'Fantasy,supernatural', 'Mystery',
#        'Fantasy,paranormal', 'Novels', 'Paranormal,wizards',
#        'Science fiction', 'Humor', 'Humor,comedy',
#        'European literature,british literature', 'Nonfiction', 'Science',
#        'History', 'Science,physics', 'Science,popular science',
#        'Historical', 'Philosophy', 'Unfinished', 'Travel',
#        'Cultural,africa', 'Autobiography,memoir', 'Eastern africa,kenya',
#        'Biography', 'Travel,travelogue', 'Language,writing',
#        'Humanities,language', 'Reference', 'Humanities,linguistics',
#        'Language,words', 'Reference,dictionaries',
#        'Writing,books about books', 'Cultural,australia',
#        'Writing,essays', 'Literature,american',
#        'The united states of america', 'Fantasy,epic fantasy',
#        'Fantasy,high fantasy', 'Literature', 'Art', 'Media tie in',
#        'Culture,film', 'Adult', 'Computer science,programming',
#        'Science,technology', 'Computer science,technical',
#        'Computer science,computers', 'Computer science,software',
#        'Science,computer science', 'Internet,web',
#        'Computer science,coding', 'Adventure,survival', 'Academic,school',
#        'Realistic fiction', 'Academic,read for school', 'Education',
#        'Biography,autobiography', 'Biography memoir',
#        'Criticism,literary criticism', 'Criticism', 'Romance',
#        'Anthologies', 'Adult fiction,erotica',
#        'Romance,paranormal romance', 'Paranormal,shapeshifters',
#        'Romance,erotic romance', 'Fantasy,urban fantasy',
#        'Paranormal,fairies', 'Fairies,fae', 'Mythology,mermaids',
#        'Fantasy,fairy tales', 'Young adult,young adult fantasy',
#        'Childrens,juvenile', 'Young adult,coming of age',
#        'Historical,historical fiction', 'Cultural,ireland',
#        'Literature,14th century', 'Historical,medieval',
#        'Literary fiction', 'European literature,irish literature', 'Lgbt',
#        'Romance,historical romance', 'Gothic', 'Literature,19th century',
#        'Cultural,african american', 'Book club', 'Race',
#        'Economics,finance', 'Economics', 'Business', 'Currency,money',
#        'Politics', 'Games,role playing games', 'Writing,journalism',
#        'Environment,nature', 'Anthologies,collections', 'Transport',
#        'Health,medicine', 'Medical', 'Health', 'Environment',
#        'Science,geology', 'Science,natural history',
#        'Science,engineering', 'Science,geography', 'War',
#        'War,military fiction', 'Military,military history',
#        'Food and drink', 'Food and drink,food', 'Short stories', 'Plays',
#        'Drama', 'Plays,theatre', 'Feminism', 'Contemporary', 'Womens',
#        'Literature,20th century', 'Teaching', 'Art,crafts',
#        'Crafts,beading', 'Christian', 'Religion,faith',
#        'Religion,christianity', 'Spirituality',
#        'Christian,christian non fiction', 'Christian,christian living',
#        'Inspirational', 'Childrens,childrens classics', 'Parenting',
#        'Self help', 'Family', 'Jewellery', 'Crafts,jewellery making',
#        'Space,space opera', 'Space', 'Speculative fiction',
#        'Southern africa,south africa', 'Leadership', 'Productivity',
#        'Performing arts', 'How to', 'Computers,internet', 'Computers',
#        'Horror', 'Food and drink,cookbooks', 'Cultural,russia',
#        'Literature,russian literature', 'Literary criticism',
#        'Womens fiction,chick lit', 'Womens fiction', 'Cultural,india',
#        'Asian literature,indian literature', 'Cultural,asia',
#        'Spy thriller,espionage', 'Crime,true crime', 'Mystery,crime',
#        'North american hi...,american history',
#        'Social movements,social justice', 'Anthropology',
#        'Social science', 'Science,astronomy',
#        'Science,history of science', 'Science fiction,time travel',
#        'Historical,stuart', 'Literature,17th century',
#        'Mystery,historical mystery', 'Thriller,mystery thriller',
#        'Mystery,detective', 'Transport,motorcycle', 'Sports,motorcycling',
#        'Science fiction,steampunk', 'Epic', 'Mystery,noir', 'Thriller',
#        'Mystery,hard boiled', 'Academic,college', 'Poetry',
#        'Childrens,picture books', 'Cultural,france',
#        'Classics,modern classics', 'Literature,banned books', 'Sexuality',
#        'Roman', 'American,americana', 'Classics,classic literature',
#        'Historical,victorian', 'European literature,french literature',
#        'War,world war ii', 'Religion', 'Religion,theology',
#        'Cultural,lebanon', 'Adventure,pirates', 'Childrens,chapter books',
#        'Magical realism', 'European literature,spanish literature',
#        'Cultural,latin american', 'Animals', 'Historical,regency',
#        'Romance,clean romance', 'European literature,german literature',
#        'Own', 'Science fiction,aliens', 'Psychology', 'Sociology',
#        'Cultural', 'Mental health,mental illness',
#        'Military history,civil war', 'Politics,presidents',
#        'American history,american civil war', 'New york',
#        'Literature,21st century', 'Music', 'Cultural,greece', 'Modern',
#        'Cultural,counter culture', 'Death', 'Adult fiction',
#        'Pseudoscience,conspiracy theories', 'Culture,society',
#        'Environment,peak oil', 'History,archaeology',
#        'Politics,political science', 'Law', 'Sports,sports',
#        'Romance,contemporary romance',
#        'Contemporary romance,sports romance',
#        'Category romance,harlequin', 'Harlequin,harlequin blaze',
#        'Sports,baseball', 'Science fiction,dystopia',
#        'Young adult,high school', 'History,ancient history',
#        'Literature,ancient', 'History,world history',
#        'Mystery,cozy mystery', 'American,southern', 'Suspense', 'Design',
#        'Design,website design', 'Textbooks', 'Art,photography',
#        'Culture,pop culture', 'Art,art design', 'Historical,georgian',
#        'Fairy tales,princesses', 'Childrens,storytime',
#        'Fairy tales,fractured fairy tales', 'Religion,buddhism',
#        'Buddhism,zen', 'Architecture', 'Business,amazon',
#        'History,medieval history', 'Religion,islam', 'Health,nutrition',
#        'Sports,fitness', 'Parenting,adoption',
#        'Science fiction,alternate history', 'Literature,jewish',
#        'Literature,latin american literature', 'Nobel prize',
#        'Science,mathematics', 'Reference,guidebook',
#        'Business,management', 'Science fiction,cyberpunk',
#        'War,terrorism', 'Academic,students', 'Hugo awards',
#        'Sports and games,games', 'Games,gaming', 'Games,chess',
#        'Games,game design', 'Design,usability', 'Christianity,catholic',
#        'Sequential art,manga', 'Sequential art,graphic novels',
#        'Sequential art,comics', 'Manga,shonen', 'Action', 'Comics manga',
#        'Cultural,italy', 'Literature,english literature', 'Relationships',
#        'Self help,personal development', 'Love', 'Northern africa,egypt',
#        'Cultural,japan', 'Asian literature,japanese literature',
#        'Finance,personal finance', 'Business,entrepreneurship',
#        'Lgbt,queer', 'Gender', 'Lgbt,transgender',
#        'Gender,gender studies', 'Glbt,queer studies', 'Queer,queer lit',
#        'Military history,american revolution',
#        'American revolution,american revolutionary war', 'Music,musicals',
#        'Cultural,china', 'Literature,asian literature',
#        'Thriller,legal thriller', 'Cities,urban planning',
#        'Geography,cities', 'Food and drink,diets',
#        'Food and drink,cooking', 'Buisness', 'Kids',
#        'Childrens,1st grade', 'New adult',
#        'European literature,italian literature', 'Food and drink,foodie',
#        'Food and drink,culinary', 'Alcohol,wine', 'Thriller,spy thriller',
#        'Health,mental health', 'Marriage',
#        'Historical fiction,prehistoric', 'Games', 'Activities',
#        'Fantasy,dragons', 'Historical fiction,historical fantasy',
#        'Fantasy,mythology', 'Humanities,classical studies',
#        'Philosophy,theory', 'Academic', 'Mythology,greek mythology',
#        'Academic,academics', 'Tragedy', 'Literature,african literature',
#        'Athens (greece)', 'Neurodiversity,autistic spectrum disorder',
#        'Superheroes,dc comics', 'Westerns', 'Lgbt,gay',
#        'Romance,m m romance', 'Political science',
#        'Church,church history', 'Reference,research', 'Humanities',
#        'Gender and sexuality', 'Occult', 'Spirituality,new age',
#        'Philosophy,metaphysics', 'Nature,outdoors',
#        'Romance,romantic suspense', 'Social issues,poverty',
#        'Social issues', 'Media tie in,tv', 'Religion,cults',
#        'Sports,mountaineering', 'Mountaineering,climbing',
#        'Young adult,teen', 'Science,biology', 'Biology,evolution',
#        'Novels,light novel', 'Religion,atheism', 'Philosophy,skepticism',
#        'Biology,neuroscience', 'Neuroscience,brain',
#        'Artificial intelligence', 'Media tie in,star trek',
#        'Linguistics,semiotics', 'Diary,journal', 'Diary', 'Fitness',
#        'Environment,climate change', 'Biology,ecology',
#        'Environment,sustainability', 'Christian fiction',
#        'Food and drink,tea', 'Presidents,us presidents',
#        'Psychology,counselling', 'Language,communication',
#        'Sports,cycling', 'Gothic,southern gothic',
#        'Mystery,murder mystery', 'Female authors', 'Disability',
#        'Horror,ghost stories', 'Paranormal,ghosts', 'Animals,cats',
#        'United states', 'Cultural,canada', 'Paranormal,witches',
#        'Cultural,international', 'Western africa,nigeria',
#        'Religion,church', 'Cultural,portugal',
#        'European literature,portuguese literature',
#        'Philosophy,eastern philosophy', 'Art,art history',
#        'Art,visual art', 'History,european history',
#        'Literature,18th century', 'Canon',
#        'Middle english li...,geoffrey chaucer', 'History,microhistory',
#        'History,food history', 'Sports,basketball',
#        'Psychology,growth mindset', 'Sociology,abuse', 'True story',
#        'Family law,fostering', 'Pop culture,geek',
#        'Culture,cultural studies', 'Race,ethnic studies', 'Art,woodwork',
#        'Holiday,christmas', 'Cultural,germany', 'India',
#        'European literature,romanian literature', 'Cultural,romania',
#        'Role playing games,dungeons and dragons',
#        'Dungeons and dragons,forgotten realms', 'Fantasy,dark fantasy',
#        'Cultural,holland', 'Autobiography', 'Media tie in,anime',
#        'Novella', 'Animals,dogs', 'Earth,the world', 'Holiday',
#        'Art,drawing', 'Short stories,short story collection',
#        'Horticulture,gardening', 'Literature,european literature',
#        'Historical,edwardian', 'Childrens,school stories',
#        'Literature,canadian literature', 'Judaism,judaica',
#        'Cultural,spain', 'Apocalyptic,post apocalyptic',
#        'Social issues,class', 'American,american fiction',
#        'Romance,love story', 'Paranormal,vampires', 'Philosophy,logic',
#        'Manga,shojo', 'Sequential art,komik',
#        'Realistic fiction,slice of life', 'Prayer', 'Cultural,scotland',
#        'Native americans', 'History,native american history',
#        'Northern africa,algeria', 'Cultural,ukraine', 'Animals,horses',
#        'Western africa,liberia', 'Futuristic', 'Romance,m f romance',
#        'Cities,urban studies', 'Science,agriculture', 'Environment,green',
#        'Politics,government', 'Religion,judaism',
#        'Food and drink,food and wine', 'Superheroes,marvel',
#        'Comics,superheroes', 'Graphic novels comics', 'Comics,comic book',
#        'Dark', 'World war ii,holocaust', 'Cities,urbanism',
#        'Religion,esoterica', 'Football', 'Soccer', 'Criticism,lit crit',
#        'Music,rock n roll', 'Social',
#        'African literature,egyptian literature',
#        'Young adult,young adult contemporary',
#        'Lovecraftian,cthulhu mythos', 'Reportage', 'History,prehistory',
#        'Health,health care', 'Young adult,young adult science fiction',
#        'Biology,genetics', 'Academic,academia', 'Reference,trivia',
#        'Alcohol,cocktails', 'Literature,15th century', 'Juvenile fiction',
#        'Media tie in,star wars', 'Psychology,psychoanalysis',
#        'Number,counting', 'Mathematics,number', 'Mathematics,division',
#        'Mathematics,multiplication', 'Northern africa,sudan',
#        'Dungeons and dragons,dragonlance', 'Manga,seinen',
#        'Sequential art,bande dessinée', 'Science fiction,utopia',
#        'Occult,mysticism', 'Couture,fashion', 'Juvenile nonfiction',
#        'American,african american literature', 'Family law,divorce',
#        'Science fiction,apocalyptic', 'American fiction',
#        'Physics,quantum mechanics', 'Business,apple', 'Cultural,israel',
#        'Labor', 'Social issues,social movements', 'Cultural,brazil',
#        'Literature,post colonial', 'Eastern africa,tanzania',
#        'Eastern africa,zambia', 'Africa,eastern africa',
#        'War,world war i', 'Animals,birds', 'Romance,christian romance',
#        'Asian literature,chinese literature', 'Biblical fiction',
#        'Biblical', 'Cultural,denmark', 'Science,chemistry',
#        'Food and drink,vegan',
#        'European literature,scandinavian literature', 'Travel,road trip',
#        'Photography', 'Thriller,psychological thriller',
#        'Art and photography', 'Fairy tales,fairy tale retellings',
#        'Homeschool', 'Social issues,activism',
#        'Christianity,discipleship', 'Paranormal,demons', 'Folklore',
#        'Folk tales', 'Shapeshifters,werewolves',
#        'Food and drink,vegetarian', 'Emergency services,police',
#        'Lgbt,lesbian', 'Romance,lesbian romance',
#        'Romance,fantasy romance', 'Erotica,menage', 'Erotica,bdsm',
#        'Menage,m m f', 'Humor,comedian', 'Animals,animal fiction',
#        'Southern africa,botswana',
#        'American civil war,civil war western theater',
#        'American civil war,civil war history',
#        'European history,french revolution', 'Sexuality,sex work',
#        'Pornography', 'Conservation', 'Religion,paganism',
#        'Cartography,maps', 'Anarchism', 'Sequential art,comix',
#        'Sequential art', 'Sequential art,graphic literature',
#        'Cultural,iran', 'European literature,czech literature',
#        'Animals,dinosaurs', 'Study aids', 'Sequential art,cartoon',
#        'Science fiction,climate change fiction',
#        'Sequential art,comic strips', 'Race,anti racist',
#        'Christianity,lds', 'Lds,lds fiction', 'Lds,mormonism',
#        'Retellings', 'Bears', 'Fairy tales,beauty and the beast',
#        'Games,video games', 'Religion,gnosticism',
#        'Young adult,young adult historical fiction', 'Science nature',
#        'Nature,plants', 'Womens studies,feminist theory',
#        'Sports,horse racing', 'Plants,herbs', 'Adventure,maritime',
#        'Historical romance,regency romance',
#        'Food and drink,food writing', 'Eastern africa,somalia',
#        'Psychology,emotion', 'Social science,social work', 'Aviation',
#        'Childrens,2nd grade', 'Horror,zombies', 'Food and drink,cuisine',
#        'Horror,bizarro fiction', 'Academic,grad school', 'Banking,banks',
#        'School stories,boarding school', 'Spiritual life',
#        'Sex work,prostitution', 'Good and evil',
#        'Romance,western romance',
#        'Historical romance,western historical romance',
#        'Holiday,halloween', 'Civil war,spanish civil war',
#        'Cultural,turkish', 'Political science,international relations',
#        'Pulp', 'Pulp,pulp adventure',
#        'International rel...,international development',
#        'Retellings,adaptations', 'Western africa,mali', 'Music,punk',
#        'English history,tudor period', 'Literature,16th century',
#        'Cultural,poland', 'European literature,polish literature',
#        'Religion,taoism', 'Christianity,old testament',
#        'Media tie in,doctor who', 'Doctors', 'Childrens,pre k',
#        'School,back to school', 'History,latin american history',
#        'The americas',
#        'Complementary med...,traditional chinese medicine',
#        'Science,library science', 'Christianity,evangelism',
#        'History,russian history', 'Dungeons and dragons (game)', 'Urban',
#        '40k', 'Gothic,gothic romance', 'Mythology,arthurian', 'Sports',
#        'Recreation', 'Eastern africa,rwanda', 'Lesbian,lesbian fiction',
#        'Folklore,monsters', 'Polyamory',
#        'Asian literature,turkish literature', 'Adolescence', 'Gardening',
#        'Sci fi fantasy', 'Occult,magick', 'Science fiction,robots',
#        'Science fiction,hard science fiction', 'Northern africa,morocco',
#        'Africa,northern africa', 'Comics', 'Graphic novels',
#        'Religion,scripture', 'Cartography,atlases', 'Alcohol,beer',
#        'Witchcraft', 'Religion,wicca', 'Occult,divination',
#        'European literature,danish', 'Outdoors,wilderness',
#        'Music,classical music', 'Graphic novels manga', 'Games,go',
#        'Manga,josei', 'Manga,manga romance', 'Fantasy,heroic fantasy',
#        'Fantasy,elves', 'Harlequin,harlequin desire',
#        'Romance,category romance', 'Transport,bicycles', 'Manga,yaoi',
#        'Yaoi,boys love', 'Cultural,belgium', 'Cultural,tasmania',
#        'Health,illness', 'Horror,lovecraftian', 'Fantasy,weird fiction',
#        'History,oral history', 'Amish', 'Religion,god',
#        'Social science,social media', 'Films and filming',
#        'Science fiction,sword and planet', 'Occult,tarot',
#        'Fantasy,unicorns', 'Science fiction,virtual reality',
#        'Medical professions,nursing', 'Dc comics,batman',
#        'Mathematics,puzzles', 'Western africa,sierra leone',
#        'Reference,field guides', 'Nature,ornithology',
#        'Pop culture,fandom', 'Railways,trains', 'Transport,railways',
#        'Finance,banking', 'Childrens,young readers', 'Gay,gay fiction',
#        'Childrens stories', 'Horror,victor frankenstein',
#        'Heroic fantasy,sword and sorcery', 'Medievalism,romanticism',
#        'Fantasy,fantasy of manners', 'Neurodiversity,adhd',
#        'Mystery,whodunit', 'Mystery,amateur sleuth',
#        'Literary collections', 'Illness,disease',
#        'German history,nazi party', 'Dc comics,superman',
#        'Marvel,spider man', 'Category romance,traditional regency',
#        'Romance,time travel romance', 'Science,earth sciences',
#        'Crafts,knitting', 'Star trek,star trek original series',
#        'Science,food science', 'Biography,music biography',
#        'Weird fiction,new weird', 'Science,pseudoscience', 'Singularity',
#        'Computers,hackers', 'Medicine,alternative medicine',
#        'Mary shelley', 'Cultural,bangladesh', 'Feminism,womens studies',
#        'Russian history,soviet union', 'Mythology,gods',
#        'Literature,13th century',
#        'European literature,swedish literature', 'Cultural,sweden',
#        'Animals,rabbits', 'Dark fantasy,goth', 'Crafts,quilting',
#        'Combat,martial arts', 'Paranormal,angels',
#        'Archaeology,egyptology', 'Military history,naval history',
#        'Transportation', 'Role playing games,world of darkness',
#        'Romance,science fiction romance', 'Category romance,silhouette',
#        'Fantasy of manners,mannerpunk', 'Astronomy,planets',
#        'Lesbian,butch femme', 'Authors', 'European',
#        'Science fiction,military science fiction', 'Antiques',
#        'Collectibles', 'Medicine,psychiatry', 'Historical,plantagenet',
#        'Reference,guides', 'Short stories,flash fiction',
#        'Folk tales,fables', 'Emergency services,firefighters',
#        'Science fiction,near future', 'History,history of medicine',
#        'Young adult,young adult romance', 'Harlequin,harlequin presents',
#        'Harlequin,hqn', 'Sports,recreation', 'Marvel,x men',
#        'Archaeology,material culture', 'Lgbt,genderqueer',
#        'Language arts', 'Disciplines', 'Surreal',
#        'Classics,cult classics', 'American literature', 'Planets,earth',
#        'Anthropology,ethnography', 'Brothers and sisters',
#        'Yaoi,shounen ai', 'World of warcraft,warcraft',
#        'Mmorpg,world of warcraft', 'Religion,hinduism', 'Cooking',
#        'Manga,yuri', 'Poetry plays', 'Manga,manhwa',
#        'Fan fiction,slash fiction', 'Body', 'Mind', 'Spirit',
#        'Religion,goddess', 'Travel,walking', 'Christianity,new testament',
#        'Transport,trucks', 'Finance,accounting',
#        'Central africa,democratic republic of the ...', 'Pets',
#        'Harlequin,harlequin romance', 'Computer science,algorithms',
#        'Stone age', 'Literature,12th century', 'Beer,brewing',
#        'Cooking,food preservation', 'Mental health.',
#        'Library science,librarianship',
#        'Historical romance,medieval romance', 'Animals,anthropomorphic',
#        'Music,musicians', 'Cultural,hungary', 'Sports,hockey',
#        'Esoterica,spiritualism', 'Gardening,horticulture',
#        'Minimal brain dysfunction in children', 'Health,physical therapy',
#        'Romantic', 'Nature', 'Social justice,social change',
#        'Category romance,loveswept',
#        'Asian literature,indonesian literature', 'Childrens poetry',
#        'Swedish', 'Spanish history,siglo de oro', 'Music,hip hop',
#        'Vegetarian,vegetarianism',
#        'Media tie in,buffy the vampire slayer', 'Italian drama',
#        'Star trek,star trek the next generation', 'Horror,splatterpunk',
#        'Pseudoscience,cryptozoology', 'Futurism',
#        'Northern africa,tunisia', 'Crafts', 'Hobbies', 'Sex',
#        'Geology,palaeontology', 'Crafts,sewing', 'Sewing,dressmaking',
#        'Fantasy,comic fantasy', 'Comedy,stand up', 'Fantasy,low fantasy',
#        'Pulp,pulp noir', 'Category romance,love inspired',
#        'Romance,interracial romance', 'Childrens,nursery rhymes',
#        'Etiquette', 'Romance,african american romance', 'Menage,m f m',
#        'Fairy tales,cinderella', 'Museology,museums',
#        'History,japanese history', 'Russian history,russian revolution',
#        'Computer software', 'Food and drink,gastronomy',
#        'History and politics', 'House', 'Home', 'Music,scores',
#        'Historical,anglo saxon', 'Vietnam war', '1961-1975',
#        'Chinese americans', 'Scandinavian lite...,nordic noir',
#        'Eastern africa,uganda', 'Wildlife', 'Star trek,star trek voyager',
#        'Science fiction,planetary romance', 'Warriors', 'Fantasy fiction',
#        'American', 'Literature,black literature',
#        'Science fiction,dying earth', 'Nursing', 'Television',
#        'Military fiction,military romance', 'Music,jazz',
#        'European literature,hungarian literature', 'Cultural,bolivia',
#        'Eastern africa,zimbabwe', 'Frontier and pioneer life',
#        'Horror,gothic horror', 'Cultural,pakistan',
#        'European literature,dutch literature',
#        'European literature,belgian', 'Christianity,church ministry',
#        'Bibles', 'Technology', 'Engineering', 'Esoterica,alchemy',
#        'Finance', 'Personal', 'Horror tales'], dtype=object)

# %%
# Objeto de tipo género
class Genre:
    def __init__(self, genreId = 0, genre_name = None):
        self.genreId = genreId
        self.genre_name = genre_name

# %%
# Conexión a base de datos
conn = None
def connect():
    global conn
    if not conn: # if conn has not been set then set
        conn = sql.connect("../db/goodreads-db.sqlite")
        conn.row_factory = sql.Row # returns a dict instead of a tuple

# %%
# Agregar género
def add_genre(genre: Genre): # needs an object that represents all of the information of the author
    sql_query = '''INSERT OR IGNORE INTO Genres (GenreName)
    VALUES (?)'''
    with closing(conn.cursor()) as cursor:
        cursor.execute(sql_query, (genre.genre_name,))
        conn.commit()

# %%
connect()
for genre_name in array_genres_unique:
    genre = Genre(genre_name=genre_name)
    add_genre(genre)
print("Tabla de géneros llenada")
# Out:
# Tabla de géneros llenada

# %% [markdown]
# Ahora llenar la tabla BookAuthors
#
# Para esto necesito primero leer los autores en base de datos, esto para obtener
# sus ids.
#
# Luego iterar por cada libro del del csv y, por cada autor de cada libro,
# generar una nueva row en la tabla BookAuthors con el id del libro y el
# id del autor

# %%
def get_authors_dictionary():
    sql_query = '''SELECT * FROM Authors'''
    df_authors = pd.read_sql_query(sql_query, conn)
    authors_dict = {}
    for index, row in df_authors.iterrows():
        authors_dict[row["AuthorName"]] = int(row["AuthorID"])
    return authors_dict

# %%
# Objeto de tipo BookAuthor
class BookAuthor:
    def __init__(self, book_id = None, author_id = None):
        self.bookId = book_id
        self.authorId = author_id

# %%
# Agregar BookAuthor
def add_bookAuthor(bookAuthor: BookAuthor):
    sql_query = '''INSERT OR IGNORE INTO BookAuthors (BookID, AuthorID)
    VALUES (?,?)'''
    with closing(conn.cursor()) as cursor:
        cursor.execute(sql_query, (int(bookAuthor.bookId), int(bookAuthor.authorId)))
        conn.commit()

# %%
authors_dict = get_authors_dictionary()
for index, row in df.iterrows():
    book_id = row["Book Id"]
    authors = row['Author']
    authors_array = authors.split("/")
    # Por cada autor, obtener su id
    for author in authors_array:
        # Quitar espacios extra
        author = " ".join(author.split())
        author_id = authors_dict.get(author)
        if(author_id != None):
            # Crear registro en la tabla BookAuthors
            bookAuthor = BookAuthor(book_id, author_id)
            add_bookAuthor(bookAuthor)
        else:
            print(f"Author {author} not found!")
print("Tabla de BookAuthors llenada")
# Out:
# Tabla de BookAuthors llenada

# %% [markdown]
# Llenar tabla BookGenres

# %%
def get_genres_dictionary():
    sql_query = '''SELECT * FROM Genres'''
    df_genres = pd.read_sql_query(sql_query, conn)
    genres_dict = {}
    for index, row in df_genres.iterrows():
        genres_dict[row["GenreName"]] = int(row["GenreID"])
    return genres_dict

# %%
# Objeto de tipo BookGenre
class BookGenre:
    def __init__(self, book_id = None, genre_id = None):
        self.bookId = book_id
        self.genreId = genre_id

# %%
# Agregar BookGenre
def add_bookGenre(bookGenre: BookGenre):
    sql_query = '''INSERT OR IGNORE INTO BookGenres (BookID, GenreID)
    VALUES (?,?)'''
    with closing(conn.cursor()) as cursor:
        cursor.execute(sql_query, (bookGenre.bookId, bookGenre.genreId))
        conn.commit()

# %%
genres_dictionary = get_genres_dictionary()
for index, row in df.iterrows():
    book_id = row["Book Id"]
    genres = row['genres']
    if(pd.isna(genres)):
        continue
    genres_array = genres.split(";")
    genres_array = [x.capitalize().strip() for x in genres_array]
    # Por cada autor, obtener su id
    for genre in genres_array:
        genre_id = genres_dictionary.get(genre)
        if(genre_id != None):
            # Crear registro en la tabla BookAuthors
            bookGenre = BookGenre(book_id, genre_id)
            add_bookGenre(bookGenre)
        else:
            print(f"Genre {genre} not found!")        

print("Tabla de BookGenres llenada")
# Out:
# Tabla de BookGenres llenada
